# %% [markdown]
# ## The point of this analysis is to see how Lebrons game has changed, how he has continued to be so dominant in the league.

# %%
import numpy as np
import pandas as pd
import xlrd

# %%
df = pd.read_csv("Lebron Data.csv")

# %%
df.head()
# Out:
#    Season   Age Team   Lg Pos     G    GS    MP    FG   FGA  ...    FT%  ORB  \
# 0  03-Apr  19.0  CLE  NBA  SG  79.0  79.0  39.5   7.9  18.9  ...  0.754  1.3
# 1  04-May  20.0  CLE  NBA  SF  80.0  80.0  42.4   9.9  21.1  ...  0.750  1.4
# 2  05-Jun  21.0  CLE  NBA  SF  79.0  79.0  42.5  11.1  23.1  ...  0.738  0.9
# 3  06-Jul  22.0  CLE  NBA  SF  78.0  78.0  40.9   9.9  20.8  ...  0.698  1.1
# 4  07-Aug  23.0  CLE  NBA  SF  75.0  74.0  40.4  10.6  21.9  ...  0.712  1.8
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.2  5.5  5.9  1.6  0.7  3.5  1.9  20.9
# 1  6.0  7.4  7.2  2.2  0.7  3.3  1.8  27.2
# 2  6.1  7.0  6.6  1.6  0.8  3.3  2.3  31.4
# 3  5.7  6.7  6.0  1.6  0.7  3.2  2.2  27.3
# 4  6.1  7.9  7.2  1.8  1.1  3.4  2.2  30.0
#
# [5 rows x 30 columns]
