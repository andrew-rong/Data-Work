# %% [markdown]
# # COVID-19 Ontario Dataset Visualization
# ## Goal is to portray Ontario as a province, and indicate the trends of COVID

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Daily_Covid_Cases.csv")
df.head()
# Out:
#          Date  Algoma_Public_Health_Unit  Brant_County_Health_Unit  \
# 0  2020-03-24                        NaN                       NaN
# 1  2020-03-25                        0.0                       1.0
# 2  2020-03-26                        0.0                       0.0
# 3  2020-03-27                        0.0                       0.0
# 4  2020-03-28                        NaN                       NaN
#
#    Chatham-Kent_Health_Unit  Durham_Region_Health_Department  \
# 0                       NaN                              NaN
# 1                       0.0                              3.0
# 2                       0.0                              1.0
# 3                       0.0                              5.0
# 4                       NaN                              NaN
#
#    Eastern_Ontario_Health_Unit  Grey_Bruce_Health_Unit  \
# 0                          NaN                     NaN
# 1                          0.0                     1.0
# ...

# %% [markdown]
# ## So we see some missing values with NaN, we will probably get rid of these values, we have enough to work with and the focus is on the individual regions in Ontario

# %%
df = df.set_index("Date")

# %%
df.head()
# Out:
#             Algoma_Public_Health_Unit  Brant_County_Health_Unit  \
# Date
# 2020-03-24                        NaN                       NaN
# 2020-03-25                        0.0                       1.0
# 2020-03-26                        0.0                       0.0
# 2020-03-27                        0.0                       0.0
# 2020-03-28                        NaN                       NaN
#
#             Chatham-Kent_Health_Unit  Durham_Region_Health_Department  \
# Date
# 2020-03-24                       NaN                              NaN
# 2020-03-25                       0.0                              3.0
# 2020-03-26                       0.0                              1.0
# 2020-03-27                       0.0                              5.0
# 2020-03-28                       NaN                              NaN
#
#             Eastern_Ontario_Health_Unit  Grey_Bruce_Health_Unit  \
# Date
# 2020-03-24                          NaN                     NaN
# ...
