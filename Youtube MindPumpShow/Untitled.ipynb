# %%
import requests
import pandas as pd
import time

# %%
with open('API.txt') as f:
    lines = f.readlines()
API_KEY = lines[0]
CHANNEL_ID = "UCq0hKkwnW5Cw1wQqu455WrA"

# %%
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=3000"
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'olYuD0_PEn48dtI2uag_xxTJcQg',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'CA',
#  'pageInfo': {'totalResults': 2843, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'BZPQPijymF_Lqd5i5JaXVSx1P70',
#    'id': {'kind': 'youtube#video', 'videoId': 'aOEc4xvK7BQ'},
#    'snippet': {'publishedAt': '2022-01-14T00:44:26Z',
#     'channelId': 'UCq0hKkwnW5Cw1wQqu455WrA',
#     'title': '1728: How Age Affects Your Ability to Build Muscle, The Best Workout Shoes, Fitness Trackers &amp; More',
#     'description': '00:00 MAPS Aesthetic Giveaway 01:11 Mind Pump Fit Tip: Contrary to popular belief, the best thing you can do for your immunity ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aOEc4xvK7BQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aOEc4xvK7BQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...
